# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import chi2_contingency

# %%
df = pd.read_csv(r"C:\Users\oussama\Desktop\PFF\generated_data\WIDE_clean.csv")
df
# Out:
#        iso_code                 region_group         income_group  \
# 0           ALB  Europe and Northern America  Upper middle income
# 1           ALB  Europe and Northern America  Upper middle income
# 2           ALB  Europe and Northern America  Upper middle income
# 3           ALB  Europe and Northern America  Upper middle income
# 4           ALB  Europe and Northern America  Upper middle income
# ...         ...                          ...                  ...
# 214977      BFA           Sub-Saharan Africa           Low income
# 214978      BFA           Sub-Saharan Africa           Low income
# 214979      BFA           Sub-Saharan Africa           Low income
# 214980      BFA           Sub-Saharan Africa           Low income
# 214981      BFA           Sub-Saharan Africa           Low income
#
#              country survey  year        category     sex location wealth  \
# 0            Albania   MICS  2000        Location     NaN    Rural    NaN
# 1            Albania   MICS  2000        Location     NaN    Urban    NaN
# 2            Albania   MICS  2000  Location & Sex  Female    Rural    NaN
# 3            Albania   MICS  2000  Location & Sex  Female    Urban    NaN
# 4            Albania   MICS  2000  Location & Sex    Male    Rural    NaN
# ...              ...    ...   ...             ...     ...      ...    ...
# 214977  Burkina Faso   HFPS  2022  Location & Sex    Male    Rural    NaN
# 214978  Burkina Faso   HFPS  2022  Location & Sex    Male    Urban    NaN
# 214979  Burkina Faso   HFPS  2022             Sex  Female      NaN    NaN
# 214980  Burkina Faso   HFPS  2022             Sex    Male      NaN    NaN
# 214981  Burkina Faso   HFPS  2022           Total     NaN      NaN    NaN
#
#         ...  rlevel3_m  rlevel3_no  slevel3_m  slevel3_no  mlevel4_m  \
# 0       ...        NaN         NaN        NaN         NaN        NaN
# 1       ...        NaN         NaN        NaN         NaN        NaN
# 2       ...        NaN         NaN        NaN         NaN        NaN
# 3       ...        NaN         NaN        NaN         NaN        NaN
# 4       ...        NaN         NaN        NaN         NaN        NaN
# ...     ...        ...         ...        ...         ...        ...
# 214977  ...        NaN         NaN        NaN         NaN        NaN
# 214978  ...        NaN         NaN        NaN         NaN        NaN
# 214979  ...        NaN         NaN        NaN         NaN        NaN
# 214980  ...        NaN         NaN        NaN         NaN        NaN
# 214981  ...        NaN         NaN        NaN         NaN        NaN
#
#         mlevel4_no  rlevel4_m  rlevel4_no  slevel4_m  slevel4_no
# 0              NaN        NaN         NaN        NaN         NaN
# 1              NaN        NaN         NaN        NaN         NaN
# 2              NaN        NaN         NaN        NaN         NaN
# 3              NaN        NaN         NaN        NaN         NaN
# 4              NaN        NaN         NaN        NaN         NaN
# ...            ...        ...         ...        ...         ...
# 214977         NaN        NaN         NaN        NaN         NaN
# 214978         NaN        NaN         NaN        NaN         NaN
# 214979         NaN        NaN         NaN        NaN         NaN
# 214980         NaN        NaN         NaN        NaN         NaN
# 214981         NaN        NaN         NaN        NaN         NaN
#
# [214982 rows x 76 columns]

# %%
df_corr = df[['comp_prim_v2_m', 
             'comp_lowsec_v2_m', 
             'comp_upsec_v2_m',
             'comp_prim_1524_m', 
             'comp_lowsec_1524_m', 
             'comp_upsec_2029_m', 
             'eduyears_2024_m', 
             'edu2_2024_m', 
             'edu4_2024_m']
             ]
plt.figure(figsize=(18,8))
plt.title("")
sns.heatmap (df_corr.corr(), cmap = 'coolwarm' ,fmt=".2f", annot= True, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Unnamed: 0 iso_code                 region_group         income_group  \
# 0         173      ALB  Europe and Northern America  Upper middle income
# 1         174      ALB  Europe and Northern America  Upper middle income
# 2         175      ALB  Europe and Northern America  Upper middle income
# 3         176      ALB  Europe and Northern America  Upper middle income
# 4         177      ALB  Europe and Northern America  Upper middle income
#
#    country survey  year        category     sex location  ... rlevel3_m  \
# 0  Albania   MICS  2000        Location     NaN    Rural  ...       NaN
# 1  Albania   MICS  2000        Location     NaN    Urban  ...       NaN
# 2  Albania   MICS  2000  Location & Sex  Female    Rural  ...       NaN
# 3  Albania   MICS  2000  Location & Sex  Female    Urban  ...       NaN
# 4  Albania   MICS  2000  Location & Sex    Male    Rural  ...       NaN
#
#    rlevel3_no  slevel3_m  slevel3_no  mlevel4_m  mlevel4_no  rlevel4_m  \
# 0         NaN        NaN         NaN        NaN         NaN        NaN
# 1         NaN        NaN         NaN        NaN         NaN        NaN
# 2         NaN        NaN         NaN        NaN         NaN        NaN
# 3         NaN        NaN         NaN        NaN         NaN        NaN
# 4         NaN        NaN         NaN        NaN         NaN        NaN
#
#    rlevel4_no  slevel4_m  slevel4_no
# 0         NaN        NaN         NaN
# 1         NaN        NaN         NaN
# 2         NaN        NaN         NaN
# 3         NaN        NaN         NaN
# 4         NaN        NaN         NaN
#
# [5 rows x 77 columns]

# %%
df_corr = df[['eduout_prim_m',
            'eduout_lowsec_m',
            'eduout_upsec_m',
            'trans_prim_m',
            'trans_lowsec_m',
            'edu0_prim_m']
        ]
plt.figure(figsize=(18,8))
plt.title("")
sns.heatmap (df_corr.corr(), cmap = 'coolwarm' ,fmt=".2f", annot= True,vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# this statistical test is to see or relise if there is any depandency between categorial variables

# %%
alpha = 0.05
df_categ  = df[['sex', 'location', 'wealth']]
for cat in df_categ:
    countingcy = pd.crosstab(df['region_group'], df_categ[cat])
    chi2_status, p, dof, ex = chi2_contingency(countingcy)
    if p < alpha:
        print("this variables are depandent")
    else:
        print("this varibles are indepandent")
print("finish")
# Out:
# this varibles are indepandent
# this variables are depandent
# this variables are depandent
# finish
