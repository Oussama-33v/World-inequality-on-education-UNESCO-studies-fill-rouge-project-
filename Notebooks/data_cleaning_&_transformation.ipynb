# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# read the data frame

# %%
df = pd.read_csv(r"C:\Users\oussama\Desktop\PFF\raw data\1699460825-wide_2023_sept (2).csv")
df
# Out:
# C:\Users\oussama\AppData\Local\Temp\ipykernel_14636\3878698096.py:1: DtypeWarning: Columns (0: level, 1: region, 2: ethnicity, 3: religion, 4: language, 5: disability, 6: hh_edu_head) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\oussama\Desktop\PFF\raw data\1699460825-wide_2023_sept (2).csv")
#         Unnamed: 0 iso_code        region_group         income_group  \
# 0            58194      GIN  Sub-Saharan Africa  Lower middle income
# 1            58434      GIN  Sub-Saharan Africa  Lower middle income
# 2            58676      GIN  Sub-Saharan Africa  Lower middle income
# 3            62010      GIN  Sub-Saharan Africa  Lower middle income
# 4            62235      GIN  Sub-Saharan Africa  Lower middle income
# ...            ...      ...                 ...                  ...
# 215573      143316      BFA  Sub-Saharan Africa           Low income
# 215574      143317      BFA  Sub-Saharan Africa           Low income
# ...

# %% [markdown]
# Top 5 rows

# %%
df.head()
# Out:
#    Unnamed: 0 iso_code        region_group         income_group country  \
# 0       58194      GIN  Sub-Saharan Africa  Lower middle income  Guinea
# 1       58434      GIN  Sub-Saharan Africa  Lower middle income  Guinea
# 2       58676      GIN  Sub-Saharan Africa  Lower middle income  Guinea
# 3       62010      GIN  Sub-Saharan Africa  Lower middle income  Guinea
# 4       62235      GIN  Sub-Saharan Africa  Lower middle income  Guinea
#
#    survey  year level  grade        category  ... rlevel3_m rlevel3_no  \
# 0  Census  1996   NaN      1           Total  ...       NaN        NaN
# 1  Census  1996   NaN      1             Sex  ...       NaN        NaN
# 2  Census  1996   NaN      1             Sex  ...       NaN        NaN
# 3  Census  1996   NaN      1        Location  ...       NaN        NaN
# 4  Census  1996   NaN      1  Location & Sex  ...       NaN        NaN
#
#   slevel3_m slevel3_no mlevel4_m mlevel4_no rlevel4_m rlevel4_no slevel4_m  \
# ...

# %% [markdown]
# Variables data types

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 215578 entries, 0 to 215577
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                215578 non-null  int64
#  1   iso_code                  215578 non-null  str
#  2   region_group              215578 non-null  str
#  3   income_group              215578 non-null  str
#  4   country                   215578 non-null  str
#  5   survey                    215578 non-null  str
#  6   year                      215578 non-null  int64
#  7   level                     58898 non-null   str
#  8   grade                     215578 non-null  int64
#  9   category                  215578 non-null  str
#  10  sex                       125646 non-null  str
#  11  location                  90348 non-null   str
#  12  wealth                    133686 non-null  str
#  13  region                    99500 non-null   str
# ...

# %% [markdown]
# trins1 : limite the datset between 2000 and 2022

# %%
df = df[(df['year'] >= 2000)]
# Out:
#         Unnamed: 0 iso_code                 region_group         income_group  \
# 173           1372      ALB  Europe and Northern America  Upper middle income
# 174           1373      ALB  Europe and Northern America  Upper middle income
# 175           1374      ALB  Europe and Northern America  Upper middle income
# 176           1375      ALB  Europe and Northern America  Upper middle income
# 177           1376      ALB  Europe and Northern America  Upper middle income
# ...            ...      ...                          ...                  ...
# 215573      143316      BFA           Sub-Saharan Africa           Low income
# 215574      143317      BFA           Sub-Saharan Africa           Low income
# 215575      143318      BFA           Sub-Saharan Africa           Low income
# 215576      143319      BFA           Sub-Saharan Africa           Low income
# 215577      143320      BFA           Sub-Saharan Africa           Low income
#
# ...

# %%
iso_code = [df['iso_code'].unique()]

# %% [markdown]
# looking for duplicate rows

# %%
#looking for duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Messing Values detect

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# iso_code             0
# region_group         0
# income_group         0
# country              0
#                  ...
# mlevel4_no      195039
# rlevel4_m       191994
# rlevel4_no      191994
# slevel4_m       195796
# slevel4_no      195796
# Length: 89, dtype: int64

# %% [markdown]
# delete culomns
# #cause : no need, had no effect on data moduling, too messing values,

# %%
df.drop(columns=['Unnamed: 0',
                        'level',
                        'grade',
                        'ethnicity',
                        'religion',
                        'disability',
                        'hh_edu_head', 
                        'disability', 
                        'disability', 
                        'disability', 
                        'preschool_3_m', 
                        'preschool_3_no', 
                        'preschool_1ybefore_m', 
                        'preschool_1ybefore_no'],inplace = True)

# %%
df['survey'].value_counts()
# Out:
# survey
# MICS      46284
# DHS       46213
# EU-LFS    27827
# TIMSS     18882
# PISA      18804
#           ...
# CS            9
# EDAM          9
# ESS           9
# NPS           9
# HFWPS         9
# Name: count, Length: 68, dtype: int64

# %%
# Keep only countries that have MORE than 100 rows of data
df = df[df.groupby('iso_code')['iso_code'].transform('count') > 100]

# %%
df
# Out:
#        iso_code                 region_group         income_group  \
# 173         ALB  Europe and Northern America  Upper middle income
# 174         ALB  Europe and Northern America  Upper middle income
# 175         ALB  Europe and Northern America  Upper middle income
# 176         ALB  Europe and Northern America  Upper middle income
# 177         ALB  Europe and Northern America  Upper middle income
# ...         ...                          ...                  ...
# 215573      BFA           Sub-Saharan Africa           Low income
# 215574      BFA           Sub-Saharan Africa           Low income
# 215575      BFA           Sub-Saharan Africa           Low income
# 215576      BFA           Sub-Saharan Africa           Low income
# 215577      BFA           Sub-Saharan Africa           Low income
#
#              country survey  year        category     sex location wealth  \
# 173          Albania   MICS  2000        Location     NaN    Rural    NaN
# ...

# %%
# Analyze outliers within specific segments rather than globally
df_low_income = df[df['income_group'] == 'Low income']
df_low_mid_income = df[df['income_group'] =='Lower middle income' ]
df_upper_mid_income = df[df['income_group'] =='Upper middle income']
df_high_income = df[df['income_group'] =='Hirgh income']

# %%
df_low_income
# Out:
#        iso_code        region_group income_group       country survey  year  \
# 421         BDI  Sub-Saharan Africa   Low income       Burundi   MICS  2000
# 422         BDI  Sub-Saharan Africa   Low income       Burundi   MICS  2000
# 423         BDI  Sub-Saharan Africa   Low income       Burundi   MICS  2000
# 424         BDI  Sub-Saharan Africa   Low income       Burundi   MICS  2000
# 425         BDI  Sub-Saharan Africa   Low income       Burundi   MICS  2000
# ...         ...                 ...          ...           ...    ...   ...
# 215573      BFA  Sub-Saharan Africa   Low income  Burkina Faso   HFPS  2022
# 215574      BFA  Sub-Saharan Africa   Low income  Burkina Faso   HFPS  2022
# 215575      BFA  Sub-Saharan Africa   Low income  Burkina Faso   HFPS  2022
# 215576      BFA  Sub-Saharan Africa   Low income  Burkina Faso   HFPS  2022
# 215577      BFA  Sub-Saharan Africa   Low income  Burkina Faso   HFPS  2022
#
# ...

# %%
MAR_educ = df[df['iso_code'] == 'MAR']

# %%
MAR_educ
MAR_educ.to_csv("MIDE.csv")

# %%
MAR_educ.isnull().sum()
# Out:
# iso_code           0
# region_group       0
# income_group       0
# country            0
# survey             0
#                 ...
# mlevel4_no      1015
# rlevel4_m        987
# rlevel4_no       987
# slevel4_m       1024
# slevel4_no      1024
# Length: 78, dtype: int64

# %%
df.to_csv("WIDE_clean.csv")
df_low_income.to_csv("low_income.csv")
df_low_mid_income.to_csv("low_mid_income.csv")
df_upper_mid_income.to_csv("upper_mid_income.csv")
df_high_income.to_csv("high_income.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 df.to_csv("WIDE_clean.csv")
# ----> 2 df_low_income.to_csv("low_income.csv")
#       3 df_low_mid_income.to_csv("low_mid_income.csv")
#       4 df_upper_mid_income.to_csv("upper_mid_income.csv")
#       5 df_high_income.to_csv("high_income.csv")
#
# File c:\Users\oussama\Desktop\PFF\venv\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3984             float_format=float_format,
#    3985             decimal=decimal,
#    3986         )
#    3987
# -> 3988         return DataFrameRenderer(formatter).to_csv(
#    3989             path_or_buf,
# ...

# %%
df = pd.read_csv(r"C:\Users\oussama\Desktop\PFF\generated_data\WIDE_clean.csv")
df
