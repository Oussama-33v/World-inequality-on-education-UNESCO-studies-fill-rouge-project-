# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
education_access  = pd.DataFrame({
    "country": [
        "Morocco", "France", "Brazil", "India", "South Africa",
        "Canada", "Kenya", "Japan"
    ],
    "year": [2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023],
    "literacy_rate": [77.3, 99.0, 93.2, 77.7, 95.0, 99.0, 82.0, 99.1],
    "school_enrollment_rate": [95, 98, 92, 88, 86, 99, 84, 100],
    "education_expenditure": [5.6, 5.2, 6.0, 4.6, 5.8, 5.5, 4.8, 3.5]
})

education_inequality = pd.DataFrame({
  "country": [
        "Morocco", "France", "Brazil", "India",
        "South Africa", "Canada", "Kenya", "Japan"
    ],
    "gender_gap_index": [
        0.72, 0.89, 0.81, 0.75,
        0.78, 0.92, 0.70, 0.95
    ],
    "dropout_rate": [
        8.5, 2.0, 6.5, 12.0,
        10.5, 1.5, 14.0, 1.0
    ],
    "urban_rural_gap": [
        15, 3, 10, 22,
        18, 2, 25, 1
    ]
})

# %%
education_access  = pd.DataFrame({
    "country": [
        "Morocco", "France", "Brazil", "India", "South Africa",
        "Canada", "Kenya", "Japan"
    ],
    "year": [2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023],
    "literacy_rate": [77.3, 99.0, 93.2, 77.7, 95.0, 99.0, 82.0, 99.1],
    "school_enrollment_rate": [95, 98, 92, 88, 86, 99, 84, 100],
    "education_expenditure": [5.6, 5.2, 6.0, 4.6, 5.8, 5.5, 4.8, 3.5]
})

education_inequality = pd.DataFrame({
  "country": [
        "Morocco", "France", "Brazil", "India",
        "South Africa", "Canada", "Kenya", "Japan"
    ],
    "gender_gap_index": [
        0.72, 0.89, 0.81, 0.75,
        0.78, 0.92, 0.70, 0.95
    ],
    "dropout_rate": [
        8.5, 2.0, 6.5, 12.0,
        10.5, 1.5, 14.0, 1.0
    ],
    "urban_rural_gap": [
        15, 3, 10, 22,
        18, 2, 25, 1
    ]
})
education_inequality.head()
education_inequality.info()
education_inequality.shepe()
education_inequality.describe()
education_inequality.isnull().sum()
education_inequality.duplecated().sum()
education_inequality

education_inequality['country'].values_count()
education_inequality['geander_gap_indes'].describe()
education_inequality['droupout_rate'].describe()

# %%
df_merged = pd.merge(education_inequality , education_access, on = 'country',  how, 'inner')
